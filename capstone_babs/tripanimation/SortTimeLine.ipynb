# %%
import sys
import csv
import datetime as datetime

# data = csv.reader(open('./data/SampleTimeline.csv','r'), delimiter=",")

# data = sorted(data, key = lambda row: datetime.datetime.strptime(row[0], '%m/%d/%y %H:%M:%S'))
# data


# # reader = csv.reader(open("files.csv"), delimiter=";")
data = csv.reader(open('./data/SampleTimeline.csv','r'), delimiter=",")
data.next()
# for time, lat, lng in data:
#     print time
#     formattedTime = datetime.datetime.strptime(time,'%m/%d/%y %H:%M:%S')
#     print formattedTime
data = sorted(data, key = lambda row: datetime.datetime.strptime(row[0], '%m/%d/%y %H:%M:%S'))
# data
# Out:
# [['08/29/13 10:17:00', '37.7710077', '-122.4026538'],
#  ['08/29/13 10:17:00', '37.7710077', '-122.4026538'],
#  ['08/29/13 10:17:10', '37.7713123245', '-122.403063679'],
#  ['08/29/13 10:17:30', '37.7713123245', '-122.403063679'],
#  ['08/29/13 10:17:30', '37.771616949', '-122.403473557'],
#  ['08/29/13 10:17:40', '37.7719215735', '-122.403883436'],
#  ['08/29/13 10:18:00', '37.771616949', '-122.403473557'],
#  ['08/29/13 10:18:00', '37.772226198', '-122.404293314'],
#  ['08/29/13 10:18:10', '37.7725308225', '-122.404703193'],
#  ['08/29/13 10:18:20', '37.7719215735', '-122.403883436'],
#  ['08/29/13 10:18:20', '37.772835447', '-122.405113072'],
#  ['08/29/13 10:18:40', '37.7731400715', '-122.40552295'],
#  ['08/29/13 10:18:50', '37.772226198', '-122.404293314'],
#  ['08/29/13 10:18:50', '37.773444696', '-122.405932829'],
#  ['08/29/13 10:19:00', '37.7737493206', '-122.406342707'],
#  ['08/29/13 10:19:20', '37.7725308225', '-122.404703193'],
# ...

# %%
# sortedTimeLine = open('./data/SortedSampleTimeline.csv', 'wb')
# wr = csv.writer(sortedTimeLine, quoting=csv.QUOTE_ALL)
# wr.writerows(data)


keys=[
 'time',
 'lat',
 'lng']

sortedTimeLine = open('./data/SortedSampleTimeline.csv', 'wb')
wr = csv.writer(sortedTimeLine, keys,delimiter=',')
wr.writerow(['time', 'lat', 'lng'])
wr.writerows(data)
