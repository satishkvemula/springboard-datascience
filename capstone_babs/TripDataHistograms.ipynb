# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
tripDurationDataFile = '201402_Trips_WithBicycleDistanceSpeed.csv'

# %%
df = pd.read_csv(tripDurationDataFile)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# plt.plot(df['Duration'])

# %%
withInOneHours=df[(df['Duration'] <= 5400) & (df['Duration'] > 60)]
betweenAnHourAndThreeHours=df[(df['Duration'] > 5400) & (df['Duration'] <= 10800 )]
extremeData=df[df['Duration'] > 10800]
print(len(withInOneHours.index))
print(len(betweenAnHourAndThreeHours.index))
print(len(extremeData.index))
# Out:
# 139668
# 2032
# 2298

# %%
plt.plot(withInOneHours['Duration'])

# %%
plt.plot(withInOneHours['distance'])

# %%
# nonExtremeData.boxplot(column='Duration') 
withInOneHours.boxplot(column='Duration', by='startStationId', figsize=(20,10)) 
# withInOneHours.boxplot(column='Duration', by='endStationId', figsize=(20,10)) 

# help(withInOneHours.boxplot)
# , by=None

# nonExtremeData.boxplot(column='Duration')

# %%
withInOneHours.boxplot(column='distance', by='startStationId', figsize=(20,10))
withInOneHours.boxplot(column='distance', by='endStationId', figsize=(20,10)) 

# nonExtremeData.boxplot(column='Duration')

# %%
withInOneHours.boxplot(column='AvgSpeed', by='startStationId', figsize=(20,10)) 
withInOneHours.boxplot(column='AvgSpeed', by='endStationId', figsize=(20,10))

# %%
# help(withInOneHours.describe())

# %%
extremeData.boxplot(column='Duration', by='startStationId', figsize=(20,10)) 
extremeData.boxplot(column='Duration', by='endStationId', figsize=(20,10))

# %%
withInOneHours=df[(df['Duration'] <= 5400) & (df['Duration'] > 60)]
