# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
tripDurationDataFile = '201402_Trips_WithBicycleDistanceSpeed.csv'

# %%
df = pd.read_csv(tripDurationDataFile)
# Out:
# /Users/p2723777/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
reasonableTrips=df[(df['Duration'] <= 2400) & (df['Duration'] > 120)]

# %%
reasonableTrips['Start Date'] = pd.to_datetime(reasonableTrips['Start Date'])  
reasonableTrips['starttime'] = reasonableTrips['Start Date'].apply(lambda x: x.weekday())
# Out:
# /Users/p2723777/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/p2723777/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
weekdayTrips = reasonableTrips[(reasonableTrips['starttime'] < 5 )]
weekendTrips = reasonableTrips[(reasonableTrips['starttime'] >4 )]

# %%
reasonableTrips.boxplot(column='Duration', by='startStationId', figsize=(20,10))
reasonableTrips.boxplot(column='Duration', by='endStationId', figsize=(20,10))

# %%
  
weekdayTrips.boxplot(column='Duration', by='startStationId', figsize=(20,10)) 
weekdayTrips.boxplot(column='Duration', by='endStationId', figsize=(20,10))

# %%
weekendTrips.boxplot(column='Duration', by='startStationId', figsize=(20,10))
weekendTrips.boxplot(column='Duration', by='endStationId', figsize=(20,10))

# %%
print(len(reasonableTrips.index))
print(len(weekdayTrips.index))
print(len(weekendTrips.index))
# Out:
# 135506
# 115984
# 19522

# %%
mondayTrips = weekdayTrips[(weekdayTrips['starttime'] ==0 )]
tuesdayTrips = weekdayTrips[(weekdayTrips['starttime'] ==1 )]
wednesTrips = weekdayTrips[(weekdayTrips['starttime'] ==2 )]
thursdayTrips = weekdayTrips[(weekdayTrips['starttime'] ==3 )]
fridayTrips = weekdayTrips[(weekdayTrips['starttime'] ==4 )]

# %%
print(len(mondayTrips.index))
print(len(tuesdayTrips.index))
print(len(wednesTrips.index))
print(len(thursdayTrips.index))
print(len(fridayTrips.index))
# Out:
# 22126
# 23791
# 22751
# 24216
# 23100

# %%
# mondayDuration = mondayTrips.loc[:,['Start Station','End Station', 'Duration']]
# mondayDurationAgg = mondayDuration.groupby(['Start Station','End Station']).count().sort_values(by='Duration', ascending=False).head(n=15)
# mondayDurationAgg
# tuesdayDuration = tuesdayTrips.loc[:,['Start Station','End Station', 'Duration']]
# tuesdayDurationAgg = tuesdayDuration.groupby(['Start Station','End Station']).count().sort_values(by='Duration', ascending=False).head(n=15)
# tuesdayDurationAggwednesDuration = wednesTrips.loc[:,['Start Station','End Station', 'Duration']]
# wednesDurationAgg = wednesDuration.groupby(['Start Station','End Station']).count().sort_values(by='Duration', ascending=False).head(n=15)
# wednesDurationAgg
# thursdayDuration = thursdayTrips.loc[:,['Start Station','End Station', 'Duration']]
# thursdayDurationAgg = thursdayDuration.groupby(['Start Station','End Station']).count().sort_values(by='Duration', ascending=False).head(n=15)
# thursdayDurationAgg
# fridayDuration = fridayTrips.loc[:,['Start Station','End Station', 'Duration']]
# fridayDurationAgg = fridayDuration.groupby(['Start Station','End Station']).count().sort_values(by='Duration', ascending=False).head(n=15)
# fridayDurationAgg

# %%
# filter out above ones by top routs
